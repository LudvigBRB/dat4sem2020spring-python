# %%
import modul1

list = {"ft.dk", "github.com", "youtube.com"}

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
#url = 'https://api.github.com/serch/repositories?q=language:python&sor' #gives 404


newThing = modul1.LoadDown(list) #Something("jeif")
link = newThing.download(url, "isitdone")

print(link.json())
type(link)
# Out:
# {'total_count': 5123731, 'incomplete_results': False, 'items': [{'id': 83222441, 'node_id': 'MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==', 'name': 'system-design-primer', 'full_name': 'donnemartin/system-design-primer', 'private': False, 'owner': {'login': 'donnemartin', 'id': 5458997, 'node_id': 'MDQ6VXNlcjU0NTg5OTc=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5458997?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donnemartin', 'html_url': 'https://github.com/donnemartin', 'followers_url': 'https://api.github.com/users/donnemartin/followers', 'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}', 'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions', 'organizations_url': 'https://api.github.com/users/donnemartin/orgs', 'repos_url': 'https://api.github.com/users
# ...

# %%
import modul1

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

modul1.download_multiple(urls)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Ludvig\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-7-9bfe77ffae23>", line 1, in <module>
#     import modul1
#
#   File "C:\Users\Ludvig\Documents\Datamatiker\4. semester\python\mitPython\06-assignment\modul1.py", line 37
#     print("\n")print("\n")
#                    ^
# SyntaxError: invalid syntax

# %%
import threading
import time
import requests

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

print(urls[2])

def get_url(url, filename):#, filename
    r = requests.get(url)
    print(r.json())
     
    with open(filename, 'wb') as fd:
        fd.write(r.content)
    
    print("Jeg er færdig")
    print("\n")
    print("\n")
    print("\n")

#for url in urls:
#    (threading.Thread(target=get_url, args=(url, url[24:27]+".txt"))).start() #, url[30:40]
    #print(url[23:30])
# Out:
# https://api.github.com/users/Thomas-Hartmann

# %%
#Denne virker i forhold til at gemme i en fil

import threading
import time
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

def get_url(url, text):
    r = requests.get(url)
    print(r.json())
    
    filename = text
    with open(filename, 'wb') as fd:
        fd.write(r.content)

(threading.Thread(target=get_url, args=(url, "aFile"))).start()
# Out:
# {'total_count': 4920088, 'incomplete_results': False, 'items': [{'id': 83222441, 'node_id': 'MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==', 'name': 'system-design-primer', 'full_name': 'donnemartin/system-design-primer', 'private': False, 'owner': {'login': 'donnemartin', 'id': 5458997, 'node_id': 'MDQ6VXNlcjU0NTg5OTc=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5458997?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donnemartin', 'html_url': 'https://github.com/donnemartin', 'followers_url': 'https://api.github.com/users/donnemartin/followers', 'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}', 'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions', 'organizations_url': 'https://api.github.com/users/donnemartin/orgs', 'repos_url': 'https://api.github.com/users
# ...

# %%
import modul1

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

thing = modul1.LoadDown(urls)

iterer = thing.urllist_generator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9dc099783176> in <module>
#       9 thing = modul1.LoadDown(urls)
#      10
# ---> 11 iterer = thing.urllist_generator()
#
# ~\Documents\Datamatiker\4. semester\python\mitPython\06-assignment\modul1.py in urllist_generator(self)
#      16
#      17     def urllist_generator(self):
# ---> 18         return iter(self.url_list)
#      19
#      20     def download(self, url, filename):
#
# TypeError: iter expected at least 1 arguments, got 0

# %%
#antal ord = antal mellemrum + 1

string = "hej med dig, du ser lidt sjov ud og ikke"

#print(string.count(" "))
#print(string.lower().count('e'))

print(map)

def checkVowel(n):
    if n == 'e' or 'a'
    return 1

print(string.lower().count('e' or 'a' or 'u'))

#[sign for sign in len(string) if sign == 'a']

#string.upper()
#print(string.upper()[4:])
# Out:
# 4

# %%
import modul1 as m

list = {"ft.dk", "github.com", "youtube.com", "dba.dk"}

thing = m.LoadDown(list)

iti = thing.iter()

#iti = iter(thing)

#iti = iter(list)

print(next(iti))
print(next(iti))
print(next(iti))
print(next(iti))
#print(next(iti))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7a251e562243> in <module>
#       5 thing = m.LoadDown(list)
#       6
# ----> 7 iti = thing.iter()
#       8
#       9 #iti = iter(thing)
#
# AttributeError: 'LoadDown' object has no attribute 'iter'
