# %%
import modul1

list = {"ft.dk", "github.com", "youtube.com"}

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

newThing = modul1.LoadDown(list) #Something("jeif")

link = newThing.download(url, "ie")
print(link.json())
type(link)
# Out:
# {'total_count': 4919535, 'incomplete_results': False, 'items': [{'id': 83222441, 'node_id': 'MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==', 'name': 'system-design-primer', 'full_name': 'donnemartin/system-design-primer', 'private': False, 'owner': {'login': 'donnemartin', 'id': 5458997, 'node_id': 'MDQ6VXNlcjU0NTg5OTc=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5458997?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donnemartin', 'html_url': 'https://github.com/donnemartin', 'followers_url': 'https://api.github.com/users/donnemartin/followers', 'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}', 'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions', 'organizations_url': 'https://api.github.com/users/donnemartin/orgs', 'repos_url': 'https://api.github.com/users/donnemartin/repos', 'events_url': 'https://api.github.com/users/donnemartin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/donnemartin/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/donnemartin/system-design-primer', 'description': 'Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.', 'fork': False, 'url': 'https://api.github.com/repos/donnemartin/system-design-primer', 'forks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/forks', 'keys_url': 'https://api.github.com/repos/donnemartin/system-design-primer/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/donnemartin/system-design-primer/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/donnemartin/system-design-primer/teams', 'hooks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/hooks', 'issue_events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/events{/number}', 'events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/events', 'assignees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/assignees{/user}', 'branches_url': 'https://api.github.com/repos/donnemartin/system-design-primer/branches{/branch}', 'tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/tags', 'blobs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/donnemartin/system-design-primer/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/donnemartin/system-design-primer/languages', 'stargazers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/stargazers', 'contributors_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contributors', 'subscribers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscribers', 'subscription_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscription', 'commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/donnemartin/system-design-primer/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contents/{+path}', 'compare_url': 'https://api.github.com/repos/donnemartin/system-design-primer/compare/{base}...{head}', 'merges_url': ...
# requests.models.Response

# %%
import modul1

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

modul1.download_multiple(urls)
# Out:
# {'login': 'Thomas-Hartmann', 'id': 9944487, 'node_id': 'MDQ6VXNlcjk5NDQ0ODc=', 'avatar_url': 'https://avatars0.githubusercontent.com/u/9944487?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Thomas-Hartmann', 'html_url': 'https://github.com/Thomas-Hartmann', 'followers_url': 'https://api.github.com/users/Thomas-Hartmann/followers', 'following_url': 'https://api.github.com/users/Thomas-Hartmann/following{/other_user}', 'gists_url': 'https://api.github.com/users/Thomas-Hartmann/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Thomas-Hartmann/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Thomas-Hartmann/subscriptions', 'organizations_url': 'https://api.github.com/users/Thomas-Hartmann/orgs', 'repos_url': 'https://api.github.com/users/Thomas-Hartmann/repos', 'events_url': 'https://api.github.com/users/Thomas-Hartmann/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Thomas-Hartmann/received_events', 'type': 'User', 'site_admin': False, 'name': 'Thomas Hartmann', 'company': 'webtrade', 'blog': '', 'location': 'Danmark', 'email': None, 'hireable': True, 'bio': None, 'public_repos': 49, 'public_gists': 36, 'followers': 15, 'following': 0, 'created_at': '2014-11-25T08:40:00Z', 'updated_at': '2020-03-04T09:16:34Z'}
# Jeg er færdig
#
#
#
#
#
#
# [{'id': '11709766211', 'type': 'PushEvent', 'actor': {'id': 60853787, 'login': 'aumi9292', 'display_login': 'aumi9292', 'gravatar_id': '', 'url': 'https://api.github.com/users/aumi9292', 'avatar_url': 'https://avatars.githubusercontent.com/u/60853787?'}, 'repo': {'id': 245698508, 'name': 'aumi9292/advanced-hashes-hashketball-denver-web-033020', 'url': 'https://api.github.com/repos/aumi9292/advanced-hashes-hashketball-denver-web-033020'}, 'payload': {'push_id': 4735694312, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/wip', 'head': 'ac98f1bd68dca0e4b18fc8e329219a9bd1b5c0ed', 'before': '522b14ec5a257419fb71d2bd7046bd20117cfa5a', 'commits': [{'sha': 'ac98f1bd68dca0e4b18fc8e329219a9bd1b5c0ed', 'author': {'email': 'austin.miller@colorado.edu', 'name': 'Austin Miller'}, 'message': 'Automatically backed up by Learn', 'distinct': True, 'url': 'https://api.github.com/repos/aumi9292/advanced-hashes-hashketball-denver-web-033020/commits/ac98f1bd68dca0e4b18fc8e329219a9bd1b5c0ed'}]}, 'public': True, 'created_at': '2020-03-08T20:42:05Z'}, {'id': '11709766208', 'type': 'PushEvent', 'actor': {'id': 57040119, 'login': 'x9mdwe5q', 'display_login': 'x9mdwe5q', 'gravatar_id': '', 'url': 'https://api.github.com/users/x9mdwe5q', 'avatar_url': 'https://avatars.githubusercontent.com/u/57040119?'}, 'repo': {'id': 236716829, 'name': 'x9mdwe5q/ncovlog', 'url': 'https://api.github.com/repos/x9mdwe5q/ncovlog'}, 'payload': {'push_id': 4735694308, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '63be1bc46479e465e2d6967dbdebe8447d64421d', 'before': '75ed397cda9daa5ce8fedf72835c4bfd591b9134', 'commits': [{'sha': '63be1bc46479e465e2d6967dbdebe8447d64421d', 'author': {'email': 'a@a.com', 'name': 'a'}, 'message': '', 'distinct': True, 'url': 'https://api.github.com/repos/x9mdwe5q/ncovlog/commits/63be1bc46479e465e2d6967dbdebe8447d64421d'}]}, 'public': True, 'created_at': '2020-03-08T20:42:05Z'}, {'id': '11709766206', 'type': 'PushEvent', 'actor': {'id': 37901431, 'login': 'JuliusAwen', 'display_login': 'JuliusAwen', 'gravatar_id': '', 'url': 'https://api.github.com/users/JuliusAwen', 'avatar_url': 'https://avatars.githubusercontent.com/u/37901431?'}, 'repo': {'id': 142578316, 'name': 'JuliusAwen/CoasterCreditCounter', 'url': 'https://api.github.com/repos/JuliusAwen/CoasterCreditCounter'}, 'payload': {'push_id': 4735694305, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '1c90a966b40ce3d2714be65570fe27dfcfa38370', 'before': 'a823e29646f94e6d0e0b6d1bfdb98c58a4bf246e', 'commits': [{'sha': '1c90a966b40ce3d2714be65570fe27dfcfa38370', 'author': {'email': 'JuliusAwen@swbmail.de', 'name': 'JuliusAwen'}, 'message': '-- rearranged mocked content: from now the annual fairs "Osterwiese" and "Freimark" will be distinct Parks for every year under the Location "Europe/Germany/Bremen" - this helps tracking visited parks count\n-- note on leaks: as it seems I was wrong: LeakCanary2 does in fact not report the notorius InputMethodManager leak any more - but there still seems to be an issue with YearDatePicker (involving the InputMethodManager). To reproduce: 1.) Navigate to any Park/ShowVisits-Tab (the rightmost tab) 2.) Click FAB to create Park (DatePickerDialog will pop up) 3.) Click on year in upper left (DatePickerDialog will change to YearPicker) 4.) Click \'cancel\' 5.) Click back button multiple times to return to NavigationHub 6.) Wait a few seconds and LeakCanary2 should report the leak', 'distinct': True, 'url': 'https://api.github.com/repos/JuliusAwen/CoasterCreditCounter/commits/1c90a966b40ce3d2714be65570fe27dfcfa38370'}]}, 'public': True, 'created_at': '2020-03-08T20:42:05Z'}, {'id': '11709766203', 'type': 'CreateEvent', 'actor': {'id': 61949510, 'login': 'CheapSheepChip', 'display_login': 'CheapSheepChip', 'gravatar_id': '', 'url': 'https://api.github.com/users/CheapSheepChip', 'avatar_url': 'https://avatars.githubusercontent.com/u/61949510?'}, 'repo': {'id': 245885069, 'name': 'CheapSheepChip/henrique', 'url': 'https://api.g ...
# Jeg er færdig
# {'total_count': 4921222, 'incomplete_results': False, 'items': [{'id': 83222441, 'node_id': 'MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==', 'name': 'system-design-primer', 'full_name': 'donnemartin/system-design-primer', 'private': False, 'owner': {'login': 'donnemartin', 'id': 5458997, 'node_id': 'MDQ6VXNlcjU0NTg5OTc=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5458997?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donnemartin', 'html_url': 'https://github.com/donnemartin', 'followers_url': 'https://api.github.com/users/donnemartin/followers', 'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}', 'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions', 'organizations_url': 'https://api.github.com/users/donnemartin/orgs', 'repos_url': 'https://api.github.com/users/donnemartin/repos', 'events_url': 'https://api.github.com/users/donnemartin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/donnemartin/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/donnemartin/system-design-primer', 'description': 'Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.', 'fork': False, 'url': 'https://api.github.com/repos/donnemartin/system-design-primer', 'forks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/forks', 'keys_url': 'https://api.github.com/repos/donnemartin/system-design-primer/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/donnemartin/system-design-primer/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/donnemartin/system-design-primer/teams', 'hooks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/hooks', 'issue_events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/events{/number}', 'events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/events', 'assignees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/assignees{/user}', 'branches_url': 'https://api.github.com/repos/donnemartin/system-design-primer/branches{/branch}', 'tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/tags', 'blobs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/donnemartin/system-design-primer/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/donnemartin/system-design-primer/languages', 'stargazers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/stargazers', 'contributors_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contributors', 'subscribers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscribers', 'subscription_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscription', 'commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/donnemartin/system-design-primer/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contents/{+path}', 'compare_url': 'https://api.github.com/repos/donnemartin/system-design-primer/compare/{base}...{head}', 'merges_url': ...
# Jeg er færdig

# %%
import threading
import time
import requests

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

print(urls[2])

def get_url(url, filename):#, filename
    r = requests.get(url)
    print(r.json())
     
    with open(filename, 'wb') as fd:
        fd.write(r.content)
    
    print("Jeg er færdig")
    print("\n")
    print("\n")
    print("\n")

#for url in urls:
#    (threading.Thread(target=get_url, args=(url, url[24:27]+".txt"))).start() #, url[30:40]
    #print(url[23:30])
# Out:
# https://api.github.com/users/Thomas-Hartmann

# %%
#Denne virker i forhold til at gemme i en fil

import threading
import time
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

def get_url(url, text):
    r = requests.get(url)
    print(r.json())
    
    filename = text
    with open(filename, 'wb') as fd:
        fd.write(r.content)

(threading.Thread(target=get_url, args=(url, "aFile"))).start()
# Out:
# {'total_count': 4920088, 'incomplete_results': False, 'items': [{'id': 83222441, 'node_id': 'MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==', 'name': 'system-design-primer', 'full_name': 'donnemartin/system-design-primer', 'private': False, 'owner': {'login': 'donnemartin', 'id': 5458997, 'node_id': 'MDQ6VXNlcjU0NTg5OTc=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5458997?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donnemartin', 'html_url': 'https://github.com/donnemartin', 'followers_url': 'https://api.github.com/users/donnemartin/followers', 'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}', 'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions', 'organizations_url': 'https://api.github.com/users/donnemartin/orgs', 'repos_url': 'https://api.github.com/users/donnemartin/repos', 'events_url': 'https://api.github.com/users/donnemartin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/donnemartin/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/donnemartin/system-design-primer', 'description': 'Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.', 'fork': False, 'url': 'https://api.github.com/repos/donnemartin/system-design-primer', 'forks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/forks', 'keys_url': 'https://api.github.com/repos/donnemartin/system-design-primer/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/donnemartin/system-design-primer/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/donnemartin/system-design-primer/teams', 'hooks_url': 'https://api.github.com/repos/donnemartin/system-design-primer/hooks', 'issue_events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/events{/number}', 'events_url': 'https://api.github.com/repos/donnemartin/system-design-primer/events', 'assignees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/assignees{/user}', 'branches_url': 'https://api.github.com/repos/donnemartin/system-design-primer/branches{/branch}', 'tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/tags', 'blobs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/donnemartin/system-design-primer/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/donnemartin/system-design-primer/languages', 'stargazers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/stargazers', 'contributors_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contributors', 'subscribers_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscribers', 'subscription_url': 'https://api.github.com/repos/donnemartin/system-design-primer/subscription', 'commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/donnemartin/system-design-primer/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/donnemartin/system-design-primer/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/donnemartin/system-design-primer/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/donnemartin/system-design-primer/contents/{+path}', 'compare_url': 'https://api.github.com/repos/donnemartin/system-design-primer/compare/{base}...{head}', 'merges_url': ...

# %%
import modul1

url1 = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
url2 = "https://api.github.com/events"
url3 = 'https://api.github.com/users/Thomas-Hartmann'

urls = [url1, url2, url3]

thing = modul1.LoadDown(urls)

iterer = thing.urllist_generator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9dc099783176> in <module>
#       9 thing = modul1.LoadDown(urls)
#      10
# ---> 11 iterer = thing.urllist_generator()
#
# ~\Documents\Datamatiker\4. semester\python\mitPython\06-assignment\modul1.py in urllist_generator(self)
#      16
#      17     def urllist_generator(self):
# ---> 18         return iter(self.url_list)
#      19
#      20     def download(self, url, filename):
#
# TypeError: iter expected at least 1 arguments, got 0

# %%
#antal ord = antal mellemrum + 1

string = "hej med dig, du ser lidt sjov ud og ikke"

#print(string.count(" "))
#print(string.lower().count('e'))

print(map)

def checkVowel(n):
    if n == 'e' or 'a'
    return 1

print(string.lower().count('e' or 'a' or 'u'))

#[sign for sign in len(string) if sign == 'a']

#string.upper()
#print(string.upper()[4:])
# Out:
# 4
